# %%
# %run functions.py

import os

# %%
url1 = 'https://www.sports-reference.com/cfb/years/'
year = 2022
url2 = '-schedule.html'
url = url1+str(year)+url2 

fbs = pd.read_csv(os.getcwd() +"\\FBS.csv")


week = 20

hfa = minimize_scalar(error_hfa, args=(url, week), method='brent', tol=0.001)['x']
decay = minimize_scalar(error_decay, bounds=(1/5,1), args=(hfa, url, week), method='bounded')['x']

hyperparameters = {
  "home_adv": hfa,
  "decay_rate": decay
}


underwood = get_underwood(year, week = week, hyperparameters = hyperparameters)
worster = get_worster(year, week = week)

underwood = underwood[underwood['team'].isin(fbs['team'])].reset_index(drop = True)
underwood.insert(loc=0, column='rank', value=range(1,132))

worster = worster[worster['team'].isin(fbs['team'])].reset_index(drop = True)
worster.insert(loc=0, column='Rank', value=range(1,132))

underwood.columns = ['Rank', 'Team', 'Rating', 'Std Dev']

graph_data = get_graph_data(2022, hyperparameters = hyperparameters)

underwood.to_csv("underwood.csv",index=False)
worster.to_csv("worster.csv", index=False)
graph_data.to_csv("graph_data.csv", index = False)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19276\1249609207.py in <module>
#      32
#      33 underwood.to_csv("underwood.csv",index=False)
# ---> 34 worster.to_csv("worster.csv", index=False)
#      35 graph_data.to_csv("graph_data.csv", index = False)
#
# ~\Anaconda3\envs\py37\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3480             doublequote=doublequote,
#    3481             escapechar=escapechar,
# -> 3482             storage_options=storage_options,
#    3483         )
#    3484
#
# ~\Anaconda3\envs\py37\lib\site-packages\pandas\io\formats\format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1103             formatter=self.fmt,
#    1104         )
# -> 1105         csv_formatter.save()
#    1106
#    1107         if created_buffer:
#
# ~\Anaconda3\envs\py37\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     241             errors=self.errors,
#     242             compression=self.compression,
# --> 243             storage_options=self.storage_options,
#     244         ) as handles:
#     245
#
# ~\Anaconda3\envs\py37\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     705                 encoding=ioargs.encoding,
#     706                 errors=errors,
# --> 707                 newline="",
#     708             )
#     709         else:
#
# PermissionError: [Errno 13] Permission denied: 'worster.csv'

# %%
underwood
# Out:
#      Rank                   Team     Rating   Std Dev
# 0       1             Ohio State  40.977476  7.565469
# 1       2                Georgia  39.170336  8.002563
# 2       3               Michigan  35.270717  6.704176
# 3       4                Alabama  33.932340  7.324163
# 4       5              Tennessee  32.761390  7.236329
# ..    ...                    ...        ...       ...
# 126   127              Charlotte -13.542738  8.698553
# 127   128  Florida International -14.809060  8.368283
# 128   129               Colorado -15.440481  6.773114
# 129   130                 Hawaii -16.120753  7.923929
# 130   131          Massachusetts -19.520850  6.636865
#
# [131 rows x 4 columns]
